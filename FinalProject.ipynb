# %% [markdown]
# ### How to import the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
beautify_pgh = pd.read_csv('Pittsburgh_Beautify_The_Burgh.csv')

# %% [markdown]
# ### Finding data to convey the cleanest

# %%
#shows the height value in each column 
beautify_pgh.max()
# Out:
# FID                           62
# Group_          Zone 9 Neighbors
# Partner                   School
# Neighborhood        West Oakland
# Council                        9
# IDNumber                      48
# SHAPE_Length             5988.16
# SHAPE_Area                305713
# dtype: object

# %%
##This line shows the number of councils of the neighborhood in decending order 
##(greatest to least). More councils = more cleanup

beautify_pgh.sort_values('Council',ascending = False)
# Out:
#     FID                                             Group_ Partner  \
# 45   53                            Pittsburgh Sterrett 6-8  School
# 40   48                                              PULSE    None
# 39   47  Point Breeze North Development Corporation (PB...    None
# 51   60                                      Heroiks, Pitt    None
# 38   46  Point Breeze North Development Corporation (PB...    None
# 37   45  Point Breeze North Development Corporation (PB...    None
# 18   21                                          Sigma Chi    OPDC
# 49   58                                 Phi Sigma Pi, Pitt    None
# 24   28                                     Sigma Alpha Mu    OPDC
# 21   25                      Alpha Phi Omega, Pitt Chapter    OPDC
# 19   22                                Triangle Fraternity    OPDC
# 22   26                                      Circle K, CMU    OPDC
# 7     9                                          Delta Chi    OPDC
# ...

# %%
## This code is to display a graph from the analysis from above.

# Read CSV into pandas
data = pd.read_csv(r"Pittsburgh_Beautify_The_Burgh.csv")
data.head()
df = pd.DataFrame(data)
 
name = df['Council'].head(12)
price = df['Neighborhood'].head(12)
 
# Figure Size
fig, ax = plt.subplots(figsize =(18, 16))
 
# Horizontal Bar Plot
ax.barh(price, name)
 
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
 
# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
 
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
 
# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='grey')
 
# Add Plot Title
ax.set_title('Number of Councils per Neighborhood')
 
# Add Text watermark
fig.text(0.9, 0.15, 'Jeeteshgavande30', fontsize = 12,
         color ='grey', ha ='right', va ='bottom',
         alpha = 0.7)
 
# Show Plot
plt.show()

# %%
beautify_pgh = sns.load_dataset('beautify_pgh')
sns.scatterplot(x='sepal_length',y='sepal_width',data=beautify_pgh,hue='species')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-69-f7d332326412> in <module>
# ----> 1 beautify_pgh = sns.load_dataset('beautify_pgh')
#       2 sns.scatterplot(x='sepal_length',y='sepal_width',data=beautify_pgh,hue='species')
#       3
#       4 plt.show()
#
# /opt/tljh/user/lib/python3.8/site-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     447                                   os.path.basename(full_path))
#     448         if not os.path.exists(cache_path):
# --> 449             urlretrieve(full_path, cache_path)
#     450         full_path = cache_path
#     451
#
# /opt/tljh/user/lib/python3.8/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = _splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# ...
