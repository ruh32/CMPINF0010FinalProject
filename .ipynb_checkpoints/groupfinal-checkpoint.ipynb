# %% [markdown]
# # The Most Environmentally Friendly Neighborhood

# %% [markdown]
# By: Ruchi Hegde, Dailynn, Le Lin

# %% [markdown]
# #### Combined Metric
#
# The combined metric is integrating the ratio of our datasets of fire incidents, the amount of smart trash cans, and the area cleaned by beautify the burgh per acre of neighborhood to determine which neighborhood is the most environmentally friendly.

# %% [markdown]
# ### Read in .CSV files

# %%
# imported in necessary libraries and read .csv files that I used throughout the whole program
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gp
cans = pd.read_csv('PittsburghSmartTrash.csv')
neighborhood = pd.read_csv('neighborhoods.csv')
fire = pd.read_csv('FireIncidents.csv')

# %% [markdown]
# ## Neighborhood Acreage

# %% [markdown]
# ### Use the neighborhood dataset to find the area in acres of each neighborhood

# %%
# uses neighborhoods.csv to make a table with just the neighborhood and acreage of each neighborhood

# created new variable that was just the columns hood and acres from the neighborhoods.csv
sortedareadf = neighborhood[['hood','acres']]
# resetted the index to not be the numbers it was in the original .csv file, just for visualization
newsortedareadf = sortedareadf.reset_index(drop=True)
# printed the table out
newsortedareadf
# Out:
#                      hood    acres
# 0                 Chateau  246.501
# 1             Summer Hill  282.104
# 2       Northview Heights  201.558
# 3   Spring Hill-City View  404.765
# 4             Perry South  581.656
# ..                    ...      ...
# 85              Overbrook  539.515
# 86         Chartiers City   84.954
# 87                 Esplen  147.829
# 88              Ridgemont  237.059
# 89               West End  128.679
#
# [90 rows x 2 columns]

# %% [markdown]
# ## Fire Incidents

# %% [markdown]
# ### Merge fire incidents with acres of each neighborhood to get table that can calculate ratio

# %%
# merged fire to neighborhood dataset to calculate ratio

# created column with number of times a neighborhood appeared, named hood and neighborhood
num = fire['neighborhood'].value_counts().to_frame().rename_axis("hood")
# renamed columns to be neighborhood and frequency
num = num.rename(columns = {"neighborhood": "frequency"})
# merged that table with the neighborhood.csv columns hood and acres
num = num.merge(sortedareadf, how = "left", left_on = "hood", right_on="hood")
# printed merged table
num
# Out:
#                          hood  frequency     acres
# 0                     Carrick        255  1075.670
# 1         Squirrel Hill South        226  1717.485
# 2   Central Business District        225   411.593
# 3            South Side Flats        220   601.553
# 4                   Hazelwood        213  1017.805
# ..                        ...        ...       ...
# 86                  St. Clair         11   199.285
# 87                 Mt. Oliver         10    66.226
# 88              East Carnegie         10   277.895
# 89              Regent Square          7   123.682
# 90       Mount Oliver Borough          6       NaN
#
# [91 rows x 3 columns]

# %%
# creating ratio column by dividing the frequency column and acres column
num["ratio"] = num["frequency"] / num["acres"]
# replacing NaN and inf values with 0, so it doesn't skew the data
num = num.replace([np.inf, -np.inf, np.NaN], 0)
# sorting the values from greatest to least by the ratio value
num = num.sort_values("ratio", ascending = False)
# printing out the table num
# we see Lincoln-Lemington-Belmar has most fires, while Hays has the least (not counting Perry North and Mount Oliver Borough)
# Perry North and Mount Oliver Borough don't really count here because both of them had an infinite value, so it was replaced with 0
num
# Out:
#                         hood  frequency     acres     ratio
# 7   Lincoln-Lemington-Belmar        174   180.105  0.966103
# 20        Marshall-Shadeland        119   148.209  0.802920
# 14                 Knoxville        147   193.982  0.757802
# 26            East Allegheny        111   151.705  0.731683
# 8             Homewood South        168   256.093  0.656012
# ..                       ...        ...       ...       ...
# 70                 Fairywood         23   622.746  0.036933
# 88             East Carnegie         10   277.895  0.035985
# 77                      Hays         18  1125.478  0.015993
# 28               Perry North        100     0.000  0.000000
# 90      Mount Oliver Borough          6     0.000  0.000000
#
# [91 rows x 4 columns]

# %% [markdown]
# ### Creating Chloropleth map with fire incident ratio

# %%
# read in the shape file with geopandas
neighborhoods = gp.read_file("Neighborhoods/Neighborhoods_.shp") 
# merged the fire incidents table with the ratio values with the shape file
fire_geo = neighborhoods.merge(num, how='left', left_on = "hood", right_on = "hood")
# printed the merged table
fire_geo
# Out:
#     objectid  fid_blockg statefp10 countyfp10 tractce10 blkgrpce10  \
# 0          1         0.0        42        003    040500          1
# 1          2         1.0        42        003    040400          1
# 2          3         2.0        42        003    040200          2
# 3          4         3.0        42        003    030500          2
# 4          5         5.0        42        003    020300          1
# ..       ...         ...       ...        ...       ...        ...
# 85        88       298.0        42        003    563100          3
# 86        89        32.0        42        003    562600          1
# 87        90        57.0        42        003    250700          1
# 88        91        96.0        42        003    562300          2
# 89      1292         NaN      None       None      None       None
#
#          geoid10     namelsad10 mtfcc10 funcstat10  ...  created_us  \
# 0   420030405001  Block Group 1   G5030          S  ...   pgh.admin
# 1   420030404001  Block Group 1   G5030          S  ...   pgh.admin
# 2   420030402002  Block Group 2   G5030          S  ...   pgh.admin
# 3   420030305002  Block Group 2   G5030          S  ...   pgh.admin
# 4   420030203001  Block Group 1   G5030          S  ...   pgh.admin
# ..           ...            ...     ...        ...  ...         ...
# 85  420035631003  Block Group 3   G5030          S  ...   pgh.admin
# 86  420035626001  Block Group 1   G5030          S  ...   pgh.admin
# 87  420032507001  Block Group 1   G5030          S  ...   pgh.admin
# 88  420035623002  Block Group 2   G5030          S  ...   pgh.admin
# 89          None           None    None       None  ...   pgh.admin
#
#                   created_da last_edite                last_edi_1  \
# 0   2019-10-23T14:17:16.403Z  pgh.admin  2019-10-23T14:17:16.403Z
# 1   2019-10-23T14:17:16.403Z  pgh.admin  2019-10-23T14:17:16.403Z
# 2   2019-10-23T14:17:16.403Z  pgh.admin  2019-10-23T14:17:16.403Z
# 3   2019-10-23T14:17:16.403Z  pgh.admin  2019-10-23T14:17:16.403Z
# 4   2019-10-23T14:17:16.403Z  pgh.admin  2019-10-23T14:17:16.403Z
# ..                       ...        ...                       ...
# 85  2019-10-23T14:17:16.403Z  pgh.admin  2019-10-23T14:17:16.403Z
# 86  2019-10-23T14:17:16.403Z  pgh.admin  2019-10-23T14:17:16.403Z
# 87  2019-10-23T14:17:16.403Z  pgh.admin  2019-10-23T14:17:16.403Z
# 88  2019-10-23T14:17:16.403Z  pgh.admin  2019-10-23T14:17:16.403Z
# 89  2019-10-23T14:17:16.403Z  pgh.admin  2019-10-23T14:17:16.403Z
#
#       Shape__Are    Shape__Len  \
# 0   7.842997e+06  11525.904546
# 1   1.390469e+07  20945.562570
# 2   5.998649e+06  18280.484515
# 3   7.203337e+06  15697.914337
# 4   1.694875e+07  24019.532672
# ..           ...           ...
# 85  1.024662e+07  16308.779881
# 86  5.579476e+06  18778.991513
# 87  6.050817e+06  11709.518764
# 88  1.271295e+07  18931.494331
# 89  3.461777e+07  31328.878632
#
#                                              geometry  frequency  acres_y  \
# 0   POLYGON ((-79.95304 40.44203, -79.95302 40.442...         83  180.883
# 1   POLYGON ((-79.95455 40.45882, -79.95427 40.458...        113  320.679
# 2   POLYGON ((-79.96230 40.44294, -79.96220 40.442...         55  138.372
# 3   POLYGON ((-79.98275 40.44641, -79.98273 40.446...         89  166.101
# 4   POLYGON ((-79.97494 40.45629, -79.97484 40.456...         47  390.864
# ..                                                ...        ...      ...
# 85  POLYGON ((-80.03431 40.43366, -80.03424 40.433...         12  237.059
# 86  POLYGON ((-80.02869 40.44454, -80.02845 40.444...         18  128.679
# 87  POLYGON ((-80.02039 40.46285, -80.02022 40.462...         35  139.552
# 88  POLYGON ((-79.92030 40.41205, -79.92027 40.412...         19  293.197
# 89  POLYGON ((-80.01783 40.49736, -80.01787 40.497...        100    0.000
#
#        ratio
# 0   0.458860
# 1   0.352377
# 2   0.397479
# 3   0.535819
# 4   0.120246
# ..       ...
# 85  0.050620
# 86  0.139883
# 87  0.250803
# 88  0.064803
# 89  0.000000
#
# [90 rows x 41 columns]

# %%
# plotted the merged fire dataset as a chloropleth map
fire_geo.plot(column='ratio', # set the ratio column to be used for coloring
               cmap='Reds',              # chose red because of the color of fire
               edgecolor="white",        # outline the districts in white
               legend=True,              # show the legend
               legend_kwds={'label': "Fire Incidents"}, # label the legend
               figsize=(15, 10),         # set the size
               )

# %% [markdown]
# This chloropleth map shows which neighborhoods had the most and least fire incidents per acre. The darker the neighborhood, the greater the ratio, the more fire incidents per acre, the least environmentally friendly areas. The graph shows that Lincoln-Lemington-Belmar in the top right corner of Pittsburgh has the most fires, meaning per this metric is it the worst neighborhood.

# %% [markdown]
# ## Smart Trash Containers

# %% [markdown]
# ### Merging smart trash cans with neighborhood area

# %%
# this table refers to the smart trash cans 
total = cans['neighborhood'].value_counts().to_frame().rename_axis("hood")
total = total.rename(columns = {"neighborhood": "frequency"})
total = total.merge(sortedareadf, how = "left", left_on = "hood", right_on="hood")
total
# Out:
#                    hood  frequency     acres
# 0             Shadyside         77   592.104
# 1          East Liberty         68   373.650
# 2   Squirrel Hill South         64  1717.485
# 3            Bloomfield         59   451.405
# 4      South Side Flats         56   601.553
# ..                  ...        ...       ...
# 74       Swisshelm Park          1   308.575
# 75          South Shore          1   136.201
# 76    Northview Heights          1   201.558
# 77        East Carnegie          1   277.895
# 78              Windgap          1   266.678
#
# [79 rows x 3 columns]

# %% [markdown]
# ### After merge, calculating the ratio of numbers of smart trashcans/acres

# %%
# creating ratio column
total["ratio"] = total["frequency"] / total["acres"]
total = total.replace([np.inf, -np.inf, np.NaN], 0)
total = total.sort_values("ratio", ascending=False)
total
# Out:
#                hood  frequency    acres     ratio
# 5       North Shore         52  195.014  0.266648
# 7   Central Oakland         39  180.883  0.215609
# 1      East Liberty         68  373.650  0.181988
# 32       Friendship         12   68.297  0.175703
# 14   East Allegheny         26  151.705  0.171385
# ..              ...        ...      ...       ...
# 78          Windgap          1  266.678  0.003750
# 77    East Carnegie          1  277.895  0.003598
# 74   Swisshelm Park          1  308.575  0.003241
# 66       Banksville          2  622.919  0.003211
# 24      Perry North         16    0.000  0.000000
#
# [79 rows x 4 columns]

# %% [markdown]
# ### Creating Chloropleth map with cans to acres ratio

# %%
# merging cans with shape file to create cans_geo
neighborhoods = gp.read_file("Neighborhoods/Neighborhoods_.shp") # read in the shapefile

cans_geo = neighborhoods.merge(total, how='left')
cans_geo
# Out:
#     objectid  fid_blockg statefp10 countyfp10 tractce10 blkgrpce10  \
# 0          1         0.0        42        003    040500          1
# 1          2         1.0        42        003    040400          1
# 2          3         2.0        42        003    040200          2
# 3          4         3.0        42        003    030500          2
# 4          5         5.0        42        003    020300          1
# ..       ...         ...       ...        ...       ...        ...
# 85        88       298.0        42        003    563100          3
# 86        89        32.0        42        003    562600          1
# 87        90        57.0        42        003    250700          1
# 88        91        96.0        42        003    562300          2
# 89      1292         NaN      None       None      None       None
#
#          geoid10     namelsad10 mtfcc10 funcstat10  ...  \
# 0   420030405001  Block Group 1   G5030          S  ...
# 1   420030404001  Block Group 1   G5030          S  ...
# 2   420030402002  Block Group 2   G5030          S  ...
# 3   420030305002  Block Group 2   G5030          S  ...
# 4   420030203001  Block Group 1   G5030          S  ...
# ..           ...            ...     ...        ...  ...
# 85  420035631003  Block Group 3   G5030          S  ...
# 86  420035626001  Block Group 1   G5030          S  ...
# 87  420032507001  Block Group 1   G5030          S  ...
# 88  420035623002  Block Group 2   G5030          S  ...
# 89          None           None    None       None  ...
#
#                plannerass  created_us                created_da last_edite  \
# 0           Derek Dauphin   pgh.admin  2019-10-23T14:17:16.403Z  pgh.admin
# 1           Derek Dauphin   pgh.admin  2019-10-23T14:17:16.403Z  pgh.admin
# 2           Derek Dauphin   pgh.admin  2019-10-23T14:17:16.403Z  pgh.admin
# 3           Derek Dauphin   pgh.admin  2019-10-23T14:17:16.403Z  pgh.admin
# 4     Andrea Lavin Kossis   pgh.admin  2019-10-23T14:17:16.403Z  pgh.admin
# ..                    ...         ...                       ...        ...
# 85         Sophia Robison   pgh.admin  2019-10-23T14:17:16.403Z  pgh.admin
# 86         Sophia Robison   pgh.admin  2019-10-23T14:17:16.403Z  pgh.admin
# 87  Stephanie Joy Everett   pgh.admin  2019-10-23T14:17:16.403Z  pgh.admin
# 88          Ose Akinlotan   pgh.admin  2019-10-23T14:17:16.403Z  pgh.admin
# 89  Stephanie Joy Everett   pgh.admin  2019-10-23T14:17:16.403Z  pgh.admin
#
#                   last_edi_1    Shape__Are    Shape__Len  \
# 0   2019-10-23T14:17:16.403Z  7.842997e+06  11525.904546
# 1   2019-10-23T14:17:16.403Z  1.390469e+07  20945.562570
# 2   2019-10-23T14:17:16.403Z  5.998649e+06  18280.484515
# 3   2019-10-23T14:17:16.403Z  7.203337e+06  15697.914337
# 4   2019-10-23T14:17:16.403Z  1.694875e+07  24019.532672
# ..                       ...           ...           ...
# 85  2019-10-23T14:17:16.403Z  1.024662e+07  16308.779881
# 86  2019-10-23T14:17:16.403Z  5.579476e+06  18778.991513
# 87  2019-10-23T14:17:16.403Z  6.050817e+06  11709.518764
# 88  2019-10-23T14:17:16.403Z  1.271295e+07  18931.494331
# 89  2019-10-23T14:17:16.403Z  3.461777e+07  31328.878632
#
#                                              geometry  frequency     ratio
# 0   POLYGON ((-79.95304 40.44203, -79.95302 40.442...        NaN       NaN
# 1   POLYGON ((-79.95455 40.45882, -79.95427 40.458...        NaN       NaN
# 2   POLYGON ((-79.96230 40.44294, -79.96220 40.442...        9.0  0.065042
# 3   POLYGON ((-79.98275 40.44641, -79.98273 40.446...       22.0  0.132450
# 4   POLYGON ((-79.97494 40.45629, -79.97484 40.456...        NaN       NaN
# ..                                                ...        ...       ...
# 85  POLYGON ((-80.03431 40.43366, -80.03424 40.433...        NaN       NaN
# 86  POLYGON ((-80.02869 40.44454, -80.02845 40.444...        9.0  0.069941
# 87  POLYGON ((-80.02039 40.46285, -80.02022 40.462...        NaN       NaN
# 88  POLYGON ((-79.92030 40.41205, -79.92027 40.412...        NaN       NaN
# 89  POLYGON ((-80.01783 40.49736, -80.01787 40.497...        NaN       NaN
#
# [90 rows x 40 columns]

# %% [markdown]
# ### Now, plot out the best neighborhood on pittsburgh map, the darkest color means the best, so north shore is best neighborhood base on the ratio of smart trash cans.

# %%
# plotting cans_geo in chloropleth map
cans_geo.plot(column='ratio', # set the data to be used for coloring
               cmap='Greens',              # choose a color palette
               edgecolor="white",        # outline the districts in white
               legend=True,              # show the legend
               legend_kwds={'label': "Number of smart trash cans"}, # label the legend
               figsize=(15, 10),         # set the size
               missing_kwds={"color": "lightgrey"} # set disctricts with no data to gray
               )

# %% [markdown]
# ## Beautify The Burgh

# %% [markdown]
# ### Merging beautified area with neighborhood area data to get a ratio
# ### Note: the area data in beautify the burgh data is sqft, so we converted to acres.

# %%
# merging beautify and neighborhood
beautify = pd.read_csv('Pittsburgh_Beautify_The_Burgh.csv')
beautify = beautify.groupby('Neighborhood').sum()
beautify['Beautified Area Sq ft'] = beautify['SHAPE_Area']
beautify['Beautified Area Acres'] = beautify['Beautified Area Sq ft'] / 4046.86
beautify['hood'] = beautify.index
beautify = beautify.merge(neighborhood)
beautify['ratios'] = beautify['Beautified Area Acres'] / beautify['acres']
beautify = beautify[['hood','Beautified Area Sq ft','acres','Beautified Area Acres', 'ratios']]
beautify = beautify.replace([np.inf, -np.inf, np.NaN], 0)
beautify = beautify.sort_values("ratios", ascending = False)
beautify
# Out:
#                          hood  Beautified Area Sq ft     acres  \
# 13           Mount Washington           1.030030e+06   732.495
# 6             Central Oakland           2.039578e+05   180.883
# 18              South Oakland           2.704829e+05   326.793
# 12        Lower Lawrenceville           2.073810e+05   276.392
# 22               West Oakland           8.054589e+04   138.372
# 14              North Oakland           1.848867e+05   320.679
# 21             Strip District           1.632250e+05   390.864
# 3                 Beltzhoover           9.549008e+04   270.374
# 20      Spring Hill-City View           1.241247e+05   404.765
# 0              Allegheny West           1.915198e+04    90.841
# 19           South Side Flats           7.128112e+04   601.553
# 5   Central Business District           3.905076e+04   411.593
# 8                     Elliott           3.386678e+04   389.870
# 7                East Liberty           3.131755e+04   373.650
# 1                   Allentown           1.517427e+04   189.608
# 2                   Arlington           2.406704e+04   302.320
# 11             Homewood South           1.929082e+04   256.093
# 15               Point Breeze           4.169019e+04   645.695
# 16                  Shadyside           2.827719e+04   592.104
# 9                  Greenfield           1.575986e+04   497.028
# 17                   Sheraden           1.602461e+04   572.125
# 4                     Carrick           1.530361e+04  1075.670
# 10                  Hazelwood           1.137505e+04  1017.805
#
#     Beautified Area Acres    ratios
# 13             254.525673  0.347478
# 6               50.399034  0.278628
# 18              66.837712  0.204526
# 12              51.244913  0.185407
# 22              19.903305  0.143839
# 14              45.686452  0.142468
# 21              40.333736  0.103191
# 3               23.596091  0.087272
# 20              30.671849  0.075777
# 0                4.732553  0.052097
# 19              17.613933  0.029281
# 5                9.649646  0.023445
# 8                8.368656  0.021465
# 7                7.738728  0.020711
# 1                3.749641  0.019776
# 2                5.947089  0.019672
# 11               4.766861  0.018614
# 15              10.301861  0.015955
# 16               6.987439  0.011801
# 9                3.894344  0.007835
# 17               3.959764  0.006921
# 4                3.781600  0.003516
# 10               2.810834  0.002762

# %% [markdown]
# ### Creating chloropleth map with ratio of beautified area to area of neighborhood
# ### Starting by import the map files

# %%
n = gp.read_file("Neighborhoods/Neighborhoods_.shp") # read in the shapefile

beautified_geo = n.merge(beautify, how='left') #merge to beautify dataframe
beautified_geo
# Out:
#     objectid  fid_blockg statefp10 countyfp10 tractce10 blkgrpce10  \
# 0          1         0.0        42        003    040500          1
# 1          2         1.0        42        003    040400          1
# 2          3         2.0        42        003    040200          2
# 3          4         3.0        42        003    030500          2
# 4          5         5.0        42        003    020300          1
# ..       ...         ...       ...        ...       ...        ...
# 85        88       298.0        42        003    563100          3
# 86        89        32.0        42        003    562600          1
# 87        90        57.0        42        003    250700          1
# 88        91        96.0        42        003    562300          2
# 89      1292         NaN      None       None      None       None
#
#          geoid10     namelsad10 mtfcc10 funcstat10  ...  created_us  \
# 0   420030405001  Block Group 1   G5030          S  ...   pgh.admin
# 1   420030404001  Block Group 1   G5030          S  ...   pgh.admin
# 2   420030402002  Block Group 2   G5030          S  ...   pgh.admin
# 3   420030305002  Block Group 2   G5030          S  ...   pgh.admin
# 4   420030203001  Block Group 1   G5030          S  ...   pgh.admin
# ..           ...            ...     ...        ...  ...         ...
# 85  420035631003  Block Group 3   G5030          S  ...   pgh.admin
# 86  420035626001  Block Group 1   G5030          S  ...   pgh.admin
# 87  420032507001  Block Group 1   G5030          S  ...   pgh.admin
# 88  420035623002  Block Group 2   G5030          S  ...   pgh.admin
# 89          None           None    None       None  ...   pgh.admin
#
#                   created_da last_edite                last_edi_1  \
# 0   2019-10-23T14:17:16.403Z  pgh.admin  2019-10-23T14:17:16.403Z
# 1   2019-10-23T14:17:16.403Z  pgh.admin  2019-10-23T14:17:16.403Z
# 2   2019-10-23T14:17:16.403Z  pgh.admin  2019-10-23T14:17:16.403Z
# 3   2019-10-23T14:17:16.403Z  pgh.admin  2019-10-23T14:17:16.403Z
# 4   2019-10-23T14:17:16.403Z  pgh.admin  2019-10-23T14:17:16.403Z
# ..                       ...        ...                       ...
# 85  2019-10-23T14:17:16.403Z  pgh.admin  2019-10-23T14:17:16.403Z
# 86  2019-10-23T14:17:16.403Z  pgh.admin  2019-10-23T14:17:16.403Z
# 87  2019-10-23T14:17:16.403Z  pgh.admin  2019-10-23T14:17:16.403Z
# 88  2019-10-23T14:17:16.403Z  pgh.admin  2019-10-23T14:17:16.403Z
# 89  2019-10-23T14:17:16.403Z  pgh.admin  2019-10-23T14:17:16.403Z
#
#       Shape__Are    Shape__Len  \
# 0   7.842997e+06  11525.904546
# 1   1.390469e+07  20945.562570
# 2   5.998649e+06  18280.484515
# 3   7.203337e+06  15697.914337
# 4   1.694875e+07  24019.532672
# ..           ...           ...
# 85  1.024662e+07  16308.779881
# 86  5.579476e+06  18778.991513
# 87  6.050817e+06  11709.518764
# 88  1.271295e+07  18931.494331
# 89  3.461777e+07  31328.878632
#
#                                              geometry  Beautified Area Sq ft  \
# 0   POLYGON ((-79.95304 40.44203, -79.95302 40.442...                    NaN
# 1   POLYGON ((-79.95455 40.45882, -79.95427 40.458...                    NaN
# 2   POLYGON ((-79.96230 40.44294, -79.96220 40.442...            80545.88713
# 3   POLYGON ((-79.98275 40.44641, -79.98273 40.446...                    NaN
# 4   POLYGON ((-79.97494 40.45629, -79.97484 40.456...                    NaN
# ..                                                ...                    ...
# 85  POLYGON ((-80.03431 40.43366, -80.03424 40.433...                    NaN
# 86  POLYGON ((-80.02869 40.44454, -80.02845 40.444...                    NaN
# 87  POLYGON ((-80.02039 40.46285, -80.02022 40.462...                    NaN
# 88  POLYGON ((-79.92030 40.41205, -79.92027 40.412...                    NaN
# 89  POLYGON ((-80.01783 40.49736, -80.01787 40.497...                    NaN
#
#     Beautified Area Acres    ratios
# 0                     NaN       NaN
# 1                     NaN       NaN
# 2               19.903305  0.143839
# 3                     NaN       NaN
# 4                     NaN       NaN
# ..                    ...       ...
# 85                    NaN       NaN
# 86                    NaN       NaN
# 87                    NaN       NaN
# 88                    NaN       NaN
# 89                    NaN       NaN
#
# [90 rows x 41 columns]

# %% [markdown]
# ### Plot out the best neighborhood base on beautify the burgh data, the darkest area is the best neighborhood.

# %%
# plot as chloropleth map
beautified_geo.plot(column='Beautified Area Sq ft', # set the data to be used for coloring
               cmap='Greens',              # choose a color palette
               edgecolor="white",        # outline the districts in white
               legend=True,              # show the legend
               legend_kwds={'label': "Beautify the Burgh"}, # label the legend
               figsize=(15, 10),         # set the size
               missing_kwds={"color": "lightgrey"} # set disctricts with no data to gray
               )

# %% [markdown]
# ### From the map shown above, the mount washington is the best neighborhood with the maximum ratio of beautify

# %% [markdown]
# ## Fire Incidents + Smart Trash Cans Combined

# %% [markdown]
# ### Merged the fire incident ratio with trash cans ratio to get a merged ratio

# %%
# combining both the ratio from the fire incidents and the ratio from the smart trash cans
rt = total.merge(num, how='left', left_on='hood', right_on='hood',suffixes=('cans','fire'))
rt['ratiofire'] = rt['ratiofire'].replace([np.inf, -np.inf, np.NaN], 0)
rt["ratio"] = rt["ratiocans"] - rt["ratiofire"]
rt.sort_values("ratio", ascending=False)
# Out:
#                         hood  frequencycans  acrescans  ratiocans  \
# 17             Regent Square              9    123.682   0.072767
# 78               Perry North             16      0.000   0.000000
# 13            Strip District             41    390.864   0.104896
# 0                North Shore             52    195.014   0.266648
# 75             East Carnegie              1    277.895   0.003598
# ..                       ...            ...        ...        ...
# 43            Homewood North              7    279.140   0.025077
# 24         Central Northside              9    166.475   0.054062
# 14        Marshall-Shadeland             15    148.209   0.101208
# 36                 Knoxville              6    193.982   0.030931
# 33  Lincoln-Lemington-Belmar              6    180.105   0.033314
#
#     frequencyfire  acresfire  ratiofire     ratio
# 17              7    123.682   0.056597  0.016171
# 78            100      0.000   0.000000  0.000000
# 13             47    390.864   0.120246 -0.015351
# 0              56    195.014   0.287159 -0.020511
# 75             10    277.895   0.035985 -0.032386
# ..            ...        ...        ...       ...
# 43            166    279.140   0.594684 -0.569607
# 24            109    166.475   0.654753 -0.600691
# 14            119    148.209   0.802920 -0.701712
# 36            147    193.982   0.757802 -0.726872
# 33            174    180.105   0.966103 -0.932789
#
# [79 rows x 8 columns]

# %% [markdown]
# ### Merged with shape file again to make sure the chloropleth map works

# %%
# merges to create fire and cans merged chloropleth map
combo1_geo = neighborhoods.merge(rt, how='left',left_on = 'hood', right_on = 'hood')
combo1_geo.head(20)
# Out:
#     objectid  fid_blockg statefp10 countyfp10 tractce10 blkgrpce10  \
# 0          1         0.0        42        003    040500          1
# 1          2         1.0        42        003    040400          1
# 2          3         2.0        42        003    040200          2
# 3          4         3.0        42        003    030500          2
# 4          5         5.0        42        003    020300          1
# 5          6         6.0        42        003    020100          4
# 6          7         7.0        42        003    262000          1
# 7          8         8.0        42        003    261500          1
# 8          9        10.0        42        003    261200          1
# 9         10        11.0        42        003    260900          1
# 10        12        13.0        42        003    563100          2
# 11        13        14.0        42        003    562400          5
# 12        14        15.0        42        003    981000          1
# 13        15        16.0        42        003    170200          1
# 14        16        19.0        42        003    180300          3
# 15        17        20.0        42        003    170600          1
# 16        18        25.0        42        003    010300          2
# 17        19        31.0        42        003    250900          2
# 18        20        34.0        42        003    562900          1
# 19        21        35.0        42        003    980000          1
#
#          geoid10     namelsad10 mtfcc10 funcstat10  ...    Shape__Are  \
# 0   420030405001  Block Group 1   G5030          S  ...  7.842997e+06
# 1   420030404001  Block Group 1   G5030          S  ...  1.390469e+07
# 2   420030402002  Block Group 2   G5030          S  ...  5.998649e+06
# 3   420030305002  Block Group 2   G5030          S  ...  7.203337e+06
# 4   420030203001  Block Group 1   G5030          S  ...  1.694875e+07
# 5   420030201004  Block Group 4   G5030          S  ...  1.784591e+07
# 6   420032620001  Block Group 1   G5030          S  ...  1.754340e+07
# 7   420032615001  Block Group 1   G5030          S  ...  2.522418e+07
# 8   420032612001  Block Group 1   G5030          S  ...  1.223253e+07
# 9   420032609001  Block Group 1   G5030          S  ...  8.727371e+06
# 10  420035631002  Block Group 2   G5030          S  ...  1.924125e+07
# 11  420035624005  Block Group 5   G5030          S  ...  1.172362e+07
# 12  420039810001  Block Group 1   G5030          S  ...  2.684814e+07
# 13  420031702001  Block Group 1   G5030          S  ...  2.608194e+07
# 14  420031803003  Block Group 3   G5030          S  ...  8.221046e+06
# 15  420031706001  Block Group 1   G5030          S  ...  1.997302e+07
# 16  420030103002  Block Group 2   G5030          S  ...  9.127091e+06
# 17  420032509002  Block Group 2   G5030          S  ...  6.962399e+06
# 18  420035629001  Block Group 1   G5030          S  ...  4.413393e+07
# 19  420039800001  Block Group 1   G5030          S  ...  5.046008e+07
#
#       Shape__Len                                           geometry  \
# 0   11525.904546  POLYGON ((-79.95304 40.44203, -79.95302 40.442...
# 1   20945.562570  POLYGON ((-79.95455 40.45882, -79.95427 40.458...
# 2   18280.484515  POLYGON ((-79.96230 40.44294, -79.96220 40.442...
# 3   15697.914337  POLYGON ((-79.98275 40.44641, -79.98273 40.446...
# 4   24019.532672  POLYGON ((-79.97494 40.45629, -79.97484 40.456...
# 5   23034.929056  POLYGON ((-79.99238 40.44484, -79.99233 40.444...
# 6   18197.706073  POLYGON ((-79.99761 40.47460, -79.99761 40.474...
# 7   26390.538103  POLYGON ((-80.01456 40.47727, -80.01462 40.477...
# 8   20906.829409  POLYGON ((-80.01087 40.50097, -80.01073 40.499...
# 9   13757.331946  POLYGON ((-80.00327 40.48271, -80.00326 40.482...
# 10  20510.080256  POLYGON ((-80.04439 40.43820, -80.04425 40.438...
# 11  13433.027976  POLYGON ((-79.99887 40.42174, -79.99853 40.421...
# 12  25436.395425  POLYGON ((-79.95393 40.47731, -79.95381 40.477...
# 13  34675.877094  POLYGON ((-79.97726 40.43274, -79.97725 40.432...
# 14  16208.014884  POLYGON ((-79.99967 40.42813, -79.99961 40.428...
# 15  26531.433744  POLYGON ((-79.99713 40.42920, -79.99547 40.428...
# 16  15724.389802  POLYGON ((-79.99390 40.43893, -79.99381 40.438...
# 17  12621.968507  POLYGON ((-80.00198 40.46814, -80.00129 40.467...
# 18  42027.889438  POLYGON ((-79.95505 40.42713, -79.95498 40.427...
# 19  41663.831329  MULTIPOLYGON (((-79.90496 40.48522, -79.90464 ...
#
#    frequencycans  acrescans  ratiocans  frequencyfire  acresfire  ratiofire  \
# 0           39.0    180.883   0.215609           83.0    180.883   0.458860
# 1           15.0    320.679   0.046776          113.0    320.679   0.352377
# 2            9.0    138.372   0.065042           55.0    138.372   0.397479
# 3           22.0    166.101   0.132450           89.0    166.101   0.535819
# 4           41.0    390.864   0.104896           47.0    390.864   0.120246
# 5            7.0    411.593   0.017007          225.0    411.593   0.546657
# 6            4.0    404.765   0.009882           95.0    404.765   0.234704
# 7            6.0    581.656   0.010315          148.0    581.656   0.254446
# 8            NaN        NaN        NaN            NaN        NaN        NaN
# 9            1.0    201.558   0.004961           60.0    201.558   0.297681
# 10           5.0    445.009   0.011236           23.0    445.009   0.051684
# 11           2.0    270.374   0.007397          115.0    270.374   0.425337
# 12          29.0    619.199   0.046835           67.0    619.199   0.108204
# 13          56.0    601.553   0.093092          220.0    601.553   0.365720
# 14          12.0    189.608   0.063288          115.0    189.608   0.606514
# 15           9.0    460.632   0.019538           82.0    460.632   0.178016
# 16          32.0    210.510   0.152012          119.0    210.510   0.565294
# 17           3.0    160.488   0.018693           45.0    160.488   0.280395
# 18          15.0   1017.805   0.014738          213.0   1017.805   0.209274
# 19           6.0    180.105   0.033314          174.0    180.105   0.966103
#
#        ratio
# 0  -0.243251
# 1  -0.305602
# 2  -0.332437
# 3  -0.403369
# 4  -0.015351
# 5  -0.529649
# 6  -0.224822
# 7  -0.244131
# 8        NaN
# 9  -0.292720
# 10 -0.040449
# 11 -0.417940
# 12 -0.061370
# 13 -0.272628
# 14 -0.543226
# 15 -0.158478
# 16 -0.413282
# 17 -0.261702
# 18 -0.194536
# 19 -0.932789
#
# [20 rows x 45 columns]

# %% [markdown]
# ### Plot with the merge data of fire incidents and smart trash cans

# %%
#chloropleth map for one merge
combo1_geo.plot(column='ratio', # set the data to be used for coloring
               cmap='Greens',              # choose a color palette
               edgecolor="white",        # outline the districts in white
               legend=True,              # show the legend
               legend_kwds={'label': "Fire Incidents and Cans"}, # label the legend
               figsize=(15, 10),         # set the size
               missing_kwds={"color": "lightgrey"} # set disctricts with no data to gray
               )

# %% [markdown]
# ## Fire Incidents, Smart Trash Cans, Beautify The Burgh - Combined Metric

# %% [markdown]
# ### Merging the combined dataset of fire incidents and smart trash cans with the beautify ratio

# %%
# merging with third dataset (beautify the burgh)
y = rt.merge(beautify, how = "left", left_on = "hood", right_on ="hood", suffixes=("ratio","realratio"))
y = y.fillna(0)
y = y.replace([np.inf, -np.inf], np.nan)
y["totalratio"] = y["ratio"] + y["ratios"]
y.head(30)
# Out:
#                      hood  frequencycans  acrescans  ratiocans  frequencyfire  \
# 0             North Shore             52    195.014   0.266648             56
# 1         Central Oakland             39    180.883   0.215609             83
# 2            East Liberty             68    373.650   0.181988            185
# 3              Friendship             12     68.297   0.175703             28
# 4          East Allegheny             26    151.705   0.171385            111
# 5          Allegheny West             14     90.841   0.154115             38
# 6                   Bluff             32    210.510   0.152012            119
# 7             Middle Hill             29    196.108   0.147878             94
# 8        Crawford-Roberts             22    166.101   0.132450             89
# 9              Bloomfield             59    451.405   0.130703            146
# 10              Shadyside             77    592.104   0.130045            154
# 11         Homewood South             30    256.093   0.117145            168
# 12    Lower Lawrenceville             29    276.392   0.104923             49
# 13         Strip District             41    390.864   0.104896             47
# 14     Marshall-Shadeland             15    148.209   0.101208            119
# 15       South Side Flats             56    601.553   0.093092            220
# 16            Polish Hill             12    163.677   0.073315             34
# 17          Regent Square              9    123.682   0.072767              7
# 18               West End              9    128.679   0.069941             18
# 19                Larimer             20    286.160   0.069891            116
# 20           West Oakland              9    138.372   0.065042             55
# 21              Allentown             12    189.608   0.063288            115
# 22    Upper Lawrenceville             16    260.349   0.061456             42
# 23              Troy Hill             15    247.170   0.060687             66
# 24      Central Northside              9    166.475   0.054062            109
# 25       Allegheny Center              7    134.703   0.051966             53
# 26  Central Lawrenceville             29    619.199   0.046835             67
# 27          North Oakland             15    320.679   0.046776            113
# 28             Upper Hill              8    201.167   0.039768             42
# 29    Squirrel Hill South             64   1717.485   0.037264            226
#
#     acresfire  ratiofire     ratio  Beautified Area Sq ft    acres  \
# 0     195.014   0.287159 -0.020511               0.000000    0.000
# 1     180.883   0.458860 -0.243251          203957.834701  180.883
# 2     373.650   0.495116 -0.313127           31317.548923  373.650
# 3      68.297   0.409974 -0.234271               0.000000    0.000
# 4     151.705   0.731683 -0.560298               0.000000    0.000
# 5      90.841   0.418313 -0.264198           19151.980159   90.841
# 6     210.510   0.565294 -0.413282               0.000000    0.000
# 7     196.108   0.479328 -0.331450               0.000000    0.000
# 8     166.101   0.535819 -0.403369               0.000000    0.000
# 9     451.405   0.323435 -0.192732               0.000000    0.000
# 10    592.104   0.260089 -0.130045           28277.186934  592.104
# 11    256.093   0.656012 -0.538867           19290.819834  256.093
# 12    276.392   0.177284 -0.072361          207380.988028  276.392
# 13    390.864   0.120246 -0.015351          163224.981728  390.864
# 14    148.209   0.802920 -0.701712               0.000000    0.000
# 15    601.553   0.365720 -0.272628           71281.121826  601.553
# 16    163.677   0.207726 -0.134411               0.000000    0.000
# 17    123.682   0.056597  0.016171               0.000000    0.000
# 18    128.679   0.139883 -0.069941               0.000000    0.000
# 19    286.160   0.405368 -0.335477               0.000000    0.000
# 20    138.372   0.397479 -0.332437           80545.887130  138.372
# 21    189.608   0.606514 -0.543226           15174.270894  189.608
# 22    260.349   0.161322 -0.099866               0.000000    0.000
# 23    247.170   0.267023 -0.206336               0.000000    0.000
# 24    166.475   0.654753 -0.600691               0.000000    0.000
# 25    134.703   0.393458 -0.341492               0.000000    0.000
# 26    619.199   0.108204 -0.061370               0.000000    0.000
# 27    320.679   0.352377 -0.305602          184886.674321  320.679
# 28    201.167   0.208782 -0.169014               0.000000    0.000
# 29   1717.485   0.131588 -0.094324               0.000000    0.000
#
#     Beautified Area Acres    ratios  totalratio
# 0                0.000000  0.000000   -0.020511
# 1               50.399034  0.278628    0.035377
# 2                7.738728  0.020711   -0.292416
# 3                0.000000  0.000000   -0.234271
# 4                0.000000  0.000000   -0.560298
# 5                4.732553  0.052097   -0.212101
# 6                0.000000  0.000000   -0.413282
# 7                0.000000  0.000000   -0.331450
# 8                0.000000  0.000000   -0.403369
# 9                0.000000  0.000000   -0.192732
# 10               6.987439  0.011801   -0.118244
# 11               4.766861  0.018614   -0.520253
# 12              51.244913  0.185407    0.113046
# 13              40.333736  0.103191    0.087841
# 14               0.000000  0.000000   -0.701712
# 15              17.613933  0.029281   -0.243347
# 16               0.000000  0.000000   -0.134411
# 17               0.000000  0.000000    0.016171
# 18               0.000000  0.000000   -0.069941
# 19               0.000000  0.000000   -0.335477
# 20              19.903305  0.143839   -0.188598
# 21               3.749641  0.019776   -0.523450
# 22               0.000000  0.000000   -0.099866
# 23               0.000000  0.000000   -0.206336
# 24               0.000000  0.000000   -0.600691
# 25               0.000000  0.000000   -0.341492
# 26               0.000000  0.000000   -0.061370
# 27              45.686452  0.142468   -0.163134
# 28               0.000000  0.000000   -0.169014
# 29               0.000000  0.000000   -0.094324

# %% [markdown]
# ### Grouping just neighborhood and the total ratio together

# %%
#groups just neighborhood and total ratio
c = y[["hood", "totalratio"]]
c.sort_values("totalratio", ascending = False)
# Out:
#                         hood  totalratio
# 34          Mount Washington    0.135872
# 12       Lower Lawrenceville    0.113046
# 13            Strip District    0.087841
# 1            Central Oakland    0.035377
# 17             Regent Square    0.016171
# ..                       ...         ...
# 43            Homewood North   -0.569607
# 24         Central Northside   -0.600691
# 14        Marshall-Shadeland   -0.701712
# 36                 Knoxville   -0.726872
# 33  Lincoln-Lemington-Belmar   -0.932789
#
# [79 rows x 2 columns]

# %% [markdown]
# ## Merging with shape file to get chloropleth map

# %%
# creating variable to read shape file and then merging it with c
neigh = gp.read_file("Neighborhoods/Neighborhoods_.shp") # read in the shapefile
combined = neigh.merge(c, how='left', left_on='hood', right_on='hood')
combined = combined.replace([np.inf, -np.inf, np.nan], 0)
# look at the head to confirm it merged correctly
combined.head()
# Out:
#    objectid  fid_blockg statefp10 countyfp10 tractce10 blkgrpce10  \
# 0         1         0.0        42        003    040500          1
# 1         2         1.0        42        003    040400          1
# 2         3         2.0        42        003    040200          2
# 3         4         3.0        42        003    030500          2
# 4         5         5.0        42        003    020300          1
#
#         geoid10     namelsad10 mtfcc10 funcstat10  ...  page_numbe  \
# 0  420030405001  Block Group 1   G5030          S  ...          15
# 1  420030404001  Block Group 1   G5030          S  ...          15
# 2  420030402002  Block Group 2   G5030          S  ...          15
# 3  420030305002  Block Group 2   G5030          S  ...          15
# 4  420030203001  Block Group 1   G5030          S  ...          15
#
#             plannerass created_us                created_da  last_edite  \
# 0        Derek Dauphin  pgh.admin  2019-10-23T14:17:16.403Z   pgh.admin
# 1        Derek Dauphin  pgh.admin  2019-10-23T14:17:16.403Z   pgh.admin
# 2        Derek Dauphin  pgh.admin  2019-10-23T14:17:16.403Z   pgh.admin
# 3        Derek Dauphin  pgh.admin  2019-10-23T14:17:16.403Z   pgh.admin
# 4  Andrea Lavin Kossis  pgh.admin  2019-10-23T14:17:16.403Z   pgh.admin
#
#                  last_edi_1    Shape__Are    Shape__Len  \
# 0  2019-10-23T14:17:16.403Z  7.842997e+06  11525.904546
# 1  2019-10-23T14:17:16.403Z  1.390469e+07  20945.562570
# 2  2019-10-23T14:17:16.403Z  5.998649e+06  18280.484515
# 3  2019-10-23T14:17:16.403Z  7.203337e+06  15697.914337
# 4  2019-10-23T14:17:16.403Z  1.694875e+07  24019.532672
#
#                                             geometry  totalratio
# 0  POLYGON ((-79.95304 40.44203, -79.95302 40.442...    0.035377
# 1  POLYGON ((-79.95455 40.45882, -79.95427 40.458...   -0.163134
# 2  POLYGON ((-79.96230 40.44294, -79.96220 40.442...   -0.188598
# 3  POLYGON ((-79.98275 40.44641, -79.98273 40.446...   -0.403369
# 4  POLYGON ((-79.97494 40.45629, -79.97484 40.456...    0.087841
#
# [5 rows x 39 columns]

# %% [markdown]
# ### Plot out the best neighborhood base on the combined metric, the result shows that Mount Washington is the most environmentally friendly neighborhood in Pittsburgh.

# %%
#plotting chloropleth map
combined.plot(column='totalratio', # set the data to be used for coloring
               cmap='Greens',              # choose a color palette
               edgecolor="white",        # outline the districts in white
               legend=True,              # show the legend
               legend_kwds={'label': "Environmental friendliness"}, # label the legend
               figsize=(15, 10),         # set the size # set disctricts with no data to gray
               )

# %% [markdown]
# Combined conclusion:
# Mount Washington is the best neighborhood and Lincoln-Lemington-Belmar is the worst neighborhood, according to our combined metric.

# %% [markdown]
# Conclusion Paragraphs:
# <br/>
# Ruchi:
# According to my personal notebook, the neighborhood with the largest ratio of trash cans to area is North Shore and the one with the least is Banksville. That is different from what the total ratio in the combined notebook tells us, however. That is because of the difference in the metric of my personal notebook and the combined noteboook. Overall, the metric of my personal one was only based off of one dataset so it did not take into consideration the other two datasets that we used in the combined. My personal metric was the number of trash cans per acre to get which neighborhood had the most trash cans and then that was added with the other two ratios to get a total ratio which weighed each metric equally.
#
# Dailynn:
# According to my notebook, the neighborhood with the largest area cleaned to area ratio is Mount Washington and the least is Hazelwood. That is different to the other notebooks because of the metrics. My metric was using the dataset to find out which neighborhood was the cleanest by doing the area of the cleaning and dividing it by the total area of the neighborhood. Through that I was able to create the ratio and compare the neighborhoods.
#
# Le Lin:
# According to the ratio of my personal data, the best neighborhood is Hays and the worst is Lincoln-Lemington-Belmar. My metric is the acre/frequency, so if the ratio is higher/lower than there are less/more fire incidents. The opposite way is frequency per acre, that means which has the highest/lowest the worst/best neighborhood. All of the conclusions are made based on my individual notebook. The Hays and Lincoln-Lemington-Belmor are the best/worst neighborhoods based on the frequency of fire incidents.
#
# All three of our datasets required the use of the Neighborhoods dataset because depending on the area of the neighborhood it could have more or less fires, smart trash cans, and area cleaned.
