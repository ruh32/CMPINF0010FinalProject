# %% [markdown]
# ## Final Project!

# %%
## import the data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
fire_incident = pd.read_csv('pittsburgh_fire_incidents.csv')

# %%
## find where most fire incidents occured
fire_incident['neighborhood'].value_counts()
# Out:
# Carrick                      255
# Central Business District    225
# Squirrel Hill South          225
# South Side Flats             219
# Hazelwood                    213
#                             ...
# St. Clair                     11
# Mt. Oliver                    10
# East Carnegie                 10
# Regent Square                  7
# Mount Oliver Borough           6
# Name: neighborhood, Length: 91, dtype: int64

# %%
## find where the least fire incidents occured.
fire_incident['neighborhood'].value_counts().idxmin()
# Out:
# 'Mount Oliver Borough'

# %%
fire_incident.groupby('neighborhood').count()
# Out:
#                      call_no  incident_type  type_description  address  \
# neighborhood
# Allegheny Center          53             52                53       53
# Allegheny West            37             37                37       37
# Allentown                115            115               115      115
# Arlington                 44             44                44       44
# Arlington Heights         12             12                12       12
# ...                      ...            ...               ...      ...
# Upper Lawrenceville       42             42                42       42
# West End                  18             18                18       18
# West Oakland              55             55                55       55
# Westwood                  23             23                23       23
# Windgap                   17             17                17       17
#
#                      alarm_time  alarms  primary_unit  census_tract  \
# neighborhood
# Allegheny Center             52      53            53            52
# Allegheny West               37      37            37            37
# Allentown                   115     115           115           115
# Arlington                    44      44            44            44
# Arlington Heights            12      12            12            12
# ...                         ...     ...           ...           ...
# Upper Lawrenceville          42      42            42            42
# West End                     18      18            18            18
# West Oakland                 55      55            55            55
# Westwood                     23      23            23            23
# Windgap                      17      17            17            17
#
#                      council_district  ward  tract  public_works_division  \
# neighborhood
# Allegheny Center                   53    53     53                     53
# Allegheny West                     37    37     37                     37
# Allentown                         115   115    115                    115
# Arlington                          44    44     44                     44
# Arlington Heights                  12    12     12                     12
# ...                               ...   ...    ...                    ...
# Upper Lawrenceville                42    42     42                     42
# West End                           18    18     18                     18
# West Oakland                       55    55     55                     55
# Westwood                           23    23     23                     23
# Windgap                            17    17     17                     17
#
#                      pli_division  police_zone  fire_zone  latitude  longitude
# neighborhood
# Allegheny Center               53           53         53        51         51
# Allegheny West                 37           37         37        36         36
# Allentown                     115          115        115       112        112
# Arlington                      44           44         44        44         44
# Arlington Heights              12           12         12        12         12
# ...                           ...          ...        ...       ...        ...
# Upper Lawrenceville            42           42         42        42         42
# West End                       18           18         18        18         18
# West Oakland                   55           55         55        55         55
# Westwood                       23           23         23        23         23
# Windgap                        17           17         17        17         17
#
# [91 rows x 17 columns]

# %%
## analyze the frequency by bar plot
fire_incident['neighborhood'].value_counts().plot.bar(figsize=(100, 100))

# %% [markdown]
# ## I decide to use both dataframe and barplot to display the frequency of fire incidents of different area, so we are not just know which area has the most/least fire incidents, but also compare with other area. The bar plot helps us to have a intuitive view.
